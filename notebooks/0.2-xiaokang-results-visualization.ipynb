# %% [markdown]
# ## Read Data

# %%
import pandas as pd
results = pd.read_csv("../data/processed/sample_and_results.csv")
results.head()
# Out:
#    OID_  SAMPLE_ID      DIST_M  NEAR_RANK     AHA_ID    ZIP  AHA_ID_lon  \
# 0  2001          1  173.323707          1  6840875.0  81648 -108.806591
# 1  2324        324  580.822403          1  6232575.0  15243  -80.066209
# 2  2306        306  264.902804          1  6230760.0  16507  -80.087927
# 3  3199       1199  160.155908          1  6640004.0  58702 -101.293818
# 4  3201       1201  497.392691          1  6640020.0  58502 -100.782259
#
#    AHA_ID_lat     ZIP_lon    ZIP_lat   BIN STATE_ABBR  Google Maps  Bing Maps  \
# 0   40.080259 -108.805998  40.078766  0-15         CO     0.883333   1.466667
# 1   40.377315  -80.072264  40.374883  0-15         PA     0.883333   0.866667
# 2   42.133525  -80.086650  42.131338  0-15         PA     1.016667   0.616667
# 3   48.232582 -101.295411  48.231612  0-15         ND     1.133333   1.033333
# 4   46.808107 -100.788736  46.808599  0-15         ND     1.450000   1.400000
#
#    ESRI Routing Service      OSRM     OSMNx  ArcGIS Pro  \
# 0              4.205097  0.913333  0.733333    0.602626
# 1              0.787713  0.825000  0.716667    0.797469
# 2              0.723206  0.693333  0.350000    0.659159
# 3              0.650208  0.381667  0.150000    0.617632
# 4              1.159282  0.875000  0.500000    1.108446
#
#    Total_Kilometers_Esri_Desktop
# 0                       0.219917
# 1                       0.594560
# 2                       0.269491
# 3                       0.298608
# 4                       0.494467

# %% [markdown]
# ## Visualize Results

# %%
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

results.index = results["Google Maps"]
ax = results.plot(kind='line',
        y=["Bing Maps", "ESRI Routing Service", "OSRM", "OSMNx", "ArcGIS Pro"],
        linewidth=0.3,alpha=0.9)
# make the line width of google maps bigger
results.plot(kind='line',y=["Google Maps"],linewidth=1.5,ax=ax)

# plt.title("Comparison of Route Drive Durations")
plt.xlabel("Google Maps Drive Time (Minute)")
plt.ylabel("Drive Time (Minute)")
# ax.set_xlim([0, 800])
# ax.set_ylim([0, 800])
# set legend line width

legend_lines = [mlines.Line2D([], [], color=c, linewidth=2) for c in plt.rcParams['axes.prop_cycle'].by_key()['color']]
legend_labels = [ "Bing Maps", "ESRI Routing Service", "OSRM", "OSMNx", "ArcGIS Pro","Google Maps"]
plt.legend(legend_lines, legend_labels,frameon=False)


plt.savefig("../reports/figures/Comparison_of_Route_Drive_Durations.png",dpi=300)
# plt.legend(["Google Map", "Bing Map", "ESRI Routing Service", "OSRM", "OSMNx", "ArcGIS Desktop"])

plt.show()
